# %% [markdown]
# # Testing your object detector

# %%
# import the necessary packages
from imutils import paths
import dlib
import cv2

# 資料視覺化模組
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# 不要顯示惱人的 warning 訊息
import warnings
warnings.filterwarnings('ignore')

# 在 Notebook 裡可即時繪圖
# %matplotlib inline  

plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams.update({'font.size':13})

# %% [markdown]
# ## Load the detector

# %%
detector = dlib.simple_object_detector("./output/stop_sign_detector.svm")

# %% [markdown]
# ## Detect the test images

# %%
# loop over the testing images
for testingPath in paths.list_images("./stop_sign_testing"):
    # load the image and make predictions
    image = cv2.imread(testingPath)
    boxes = detector(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    # loop over the bounding boxes and draw them
    for b in boxes:
        (x, y, w, h) = (b.left(), b.top(), b.right(), b.bottom())
        cv2.rectangle(image, (x, y), (w, h), (0, 255, 0), 2)

    # show the image
    plt.title("Image")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()

# %% [markdown]
# ## My testing

# %%
# loop over the testing images
for testingPath in paths.list_images("./my_testing"):
    # load the image and make predictions
    image = cv2.imread(testingPath)
    boxes = detector(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    # loop over the bounding boxes and draw them
    for b in boxes:
        (x, y, w, h) = (b.left(), b.top(), b.right(), b.bottom())
        cv2.rectangle(image, (x, y), (w, h), (0, 255, 0), 2)

    # show the image
    plt.title("Image")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()

# %% [markdown]
# # Quiz

# %%
detector2 = dlib.simple_object_detector("./output/sunflower_detector.svm")

# %%
# load the image and make predictions
image2 = cv2.imread("./sunflower.jpg")
boxes2 = detector(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))

# loop over the bounding boxes and draw them
for b in boxes2:
    (x, y, w, h) = (b.left(), b.top(), b.right(), b.bottom())
    cv2.rectangle(image2, (x, y), (w, h), (0, 255, 0), 2)

    # show the image
    plt.title("Image: X={}, Y={}, W={}, H={}".format(x,y,w,h))
    plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# X: 136, Y: 50, W: 394, H: 308
