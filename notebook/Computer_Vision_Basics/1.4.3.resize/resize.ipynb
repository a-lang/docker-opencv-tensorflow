# %% [markdown]
# # Resizing

# %%
import numpy as np
import imutils
import cv2

# 資料視覺化模組
import matplotlib.pyplot as plt

# 不要顯示惱人的 warning 訊息
import warnings
warnings.filterwarnings('ignore')

# 在 Notebook 裡可即時繪圖
# %matplotlib inline  

plt.rcParams['figure.figsize'] = [15, 7]
plt.rcParams.update({'font.size':13})

# %%
# load the image and show it
image = cv2.imread("../input/florida_trip_small.png")

plt.title("Original")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
r = 150.0 / image.shape[1]
dim = (150, int(image.shape[0] * r))

# perform the actual resizing of the image
resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)

plt.title("Resized (Width=150)")
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
r = 50.0 / image.shape[0]
dim = (int(image.shape[1] * r), 50)

# perform the resizing
resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)

plt.title("Resized (Height=50)")
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resized = imutils.resize(image, width=100)

plt.title("Resized via Function(Width=100)")
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Interpolation Methods

# %%
# construct the list of interpolation methods
methods = [
    ("cv2.INTER_NEAREST", cv2.INTER_NEAREST),
    ("cv2.INTER_LINEAR", cv2.INTER_LINEAR),
    ("cv2.INTER_AREA", cv2.INTER_AREA),
    ("cv2.INTER_CUBIC", cv2.INTER_CUBIC),
    ("cv2.INTER_LANCZOS4", cv2.INTER_LANCZOS4)]

# loop over the interpolation methods
for (name, method) in methods:
    # increase the size of the image by 3x using the current interpolation
    # method
    resized = imutils.resize(image, width=image.shape[1] * 3, inter=method)
    plt.title("Method: {}".format(name))
    plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
    plt.show()

# %% [markdown]
# ## Quiz

# %%
resized = imutils.resize(image, width=100, inter=cv2.INTER_NEAREST)
(b, g, r) = resized[74, 20]
print("R: {r}, G: {g}, B: {b}".format(b=b, g=g, r=r))
# Out:
# R: 16, G: 19, B: 26

# %%
w = image.shape[1]
twice = imutils.resize(image, width=w*2, inter=cv2.INTER_CUBIC)
(b, g, r) = twice[367, 170]
print("R: {r}, G: {g}, B: {b}".format(b=b, g=g, r=r))

plt.title("Twice Image")
plt.imshow(cv2.cvtColor(twice, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# R: 20, G: 20, B: 25
