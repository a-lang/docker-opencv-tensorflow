# %% [markdown]
# # Edge detection
# ## Automatically tuning edge detection parameters

# %%
import numpy as np
import imutils
import cv2

# 資料視覺化模組
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# 不要顯示惱人的 warning 訊息
import warnings
warnings.filterwarnings('ignore')

# 在 Notebook 裡可即時繪圖
# %matplotlib inline  

plt.rcParams['figure.figsize'] = [15, 7]
plt.rcParams.update({'font.size':13})

# %% [markdown]
# ## Example: teacup.jpg

# %%
# load the image, convert it to grayscale, and blur it slightly
image = cv2.imread("../input/teacup.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)

# apply Canny edge detection using a wide threshold, tight
# threshold, and automatically determined threshold
wide = cv2.Canny(blurred, 10, 200)
tight = cv2.Canny(blurred, 225, 250)
auto = imutils.auto_canny(blurred)

# show the images
plt.title("Original")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

plt.title("Wide")
plt.imshow(wide, cmap="gray")
plt.show()

plt.title("Tight")
plt.imshow(tight, cmap="gray")
plt.show()

plt.title("Auto")
plt.imshow(auto, cmap="gray")
plt.show()

# %% [markdown]
# ## Example: clonazepam_1mg.png

# %%
# load the image, convert it to grayscale, and blur it slightly
image = cv2.imread("../input/clonazepam_1mg.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)

# apply Canny edge detection using a wide threshold, tight
# threshold, and automatically determined threshold
wide = cv2.Canny(blurred, 10, 200)
tight = cv2.Canny(blurred, 225, 250)
auto = imutils.auto_canny(blurred)

# show the images
plt.title("Original")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

plt.title("Wide")
plt.imshow(wide, cmap="gray")
plt.show()

plt.title("Tight")
plt.imshow(tight, cmap="gray")
plt.show()

plt.title("Auto")
plt.imshow(auto, cmap="gray")
plt.show()

# %% [markdown]
# ## Example: coins02.png

# %%
# load the image, convert it to grayscale, and blur it slightly
image = cv2.imread("../input/coins02.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)

# apply Canny edge detection using a wide threshold, tight
# threshold, and automatically determined threshold
wide = cv2.Canny(blurred, 10, 200)
tight = cv2.Canny(blurred, 225, 250)
auto = imutils.auto_canny(blurred)

# show the images
plt.title("Original")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

plt.title("Wide")
plt.imshow(wide, cmap="gray")
plt.show()

plt.title("Tight")
plt.imshow(tight, cmap="gray")
plt.show()

plt.title("Auto")
plt.imshow(auto, cmap="gray")
plt.show()
